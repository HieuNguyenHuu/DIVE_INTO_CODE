# %% [markdown]
# # Mathematics for Machine Learning Pre-Class assignment 1 Wheat and Chessboard Problem

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <hr>
#
# **[Problem 1] Number of wheat on a 2 x 2 square chess board**
#
# <hr>

# %%
n_squares = 4
small_board_list = [1]
for i in range(n_squares - 1):
    small_board_list.append(2*small_board_list[-1])

small_board_ndarray = np.array(small_board_list)

square_array = small_board_ndarray.reshape(2,2)

for i,value in enumerate(square_array):
    for j, value in enumerate(value):
        print("number of wheat in square [{},{}] : {}".format(j+1,i+1,value))
# Out:
# number of wheat in square [1,1] : 1
# number of wheat in square [2,1] : 2
# number of wheat in square [1,2] : 4
# number of wheat in square [2,2] : 8

# %% [markdown]
# <hr>
#
# **[Problem 2] Expansion to n × m mass**
#
# <hr>

# %%
def mxn_mass(m, n):
    t0 = 1 
    lists = [t0]
    for i in range(m*n - 1):
        lists.append(lists[-1]*2) 
    arr = np.array(lists)
    arr = arr.reshape(m,n)
    
    return arr

arr = mxn_mass(2, 3)

print("run function in simple example 2x3 for checking : ")
print(arr.sum())
print("\n")


arr = mxn_mass(8, 8)

for i,value in enumerate(arr):
    for j, value in enumerate(value):
        print("number of wheat in square [{},{}] : {}".format(j,i,int(value)))
# Out:
# run function in simple example 2x3 for checking :
# 63
#
#
# number of wheat in square [0,0] : 1
# number of wheat in square [1,0] : 2
# number of wheat in square [2,0] : 4
# number of wheat in square [3,0] : 8
# number of wheat in square [4,0] : 16
# number of wheat in square [5,0] : 32
# number of wheat in square [6,0] : 64
# number of wheat in square [7,0] : 128
# number of wheat in square [0,1] : 256
# number of wheat in square [1,1] : 512
# number of wheat in square [2,1] : 1024
# number of wheat in square [3,1] : 2048
# number of wheat in square [4,1] : 4096
# number of wheat in square [5,1] : 8192
# number of wheat in square [6,1] : 16384
# number of wheat in square [7,1] : 32768
# number of wheat in square [0,2] : 65536
# number of wheat in square [1,2] : 131072
# number of wheat in square [2,2] : 262144
# number of wheat in square [3,2] : 524288
# number of wheat in square [4,2] : 1048576
# number of wheat in square [5,2] : 2097152
# ...

# %% [markdown]
# <hr>
#
# **[Problem 3] Total number of wheat**
#
# <hr>

# %%
print("Total wheat on a chess board of 8x8 squares : {} x 10^18\n".format(arr.sum()/ (10**18)))

sum_column = arr.sum(axis = 0)

print("the average of each column in 8x8 square\n")
print(sum_column)
print("\n")

plt.title("the average of each column in 8x8 square")
plt.xlabel("column")
plt.ylabel("average number")
for i in range(len(sum_column)):
    plt.text(i+1, sum_column[i] + 0.2 * (10**18), "{:.2f}".format(sum_column[i]/(10**18)), horizontalalignment='center',verticalalignment='center', size = 10)
plt.bar(np.arange(1, len(sum_column)+1 , 1), sum_column )
plt.show()
# Out:
# Total wheat on a chess board of 8x8 squares : 18.446744073709553 x 10^18
#
# the average of each column in 8x8 square
#
# [7.23401728e+16 1.44680346e+17 2.89360691e+17 5.78721383e+17
#  1.15744277e+18 2.31488553e+18 4.62977106e+18 9.25954212e+18]

# %% [markdown]
# <hr>
#
# **[Problem 4] Heat map of the number of wheat**
#
# <hr>

# %%
plt.xlabel("column")
plt.ylabel("row")
plt.title("heatmap for 8x8 squares")
plt.pcolor(arr)
plt.show()

# %% [markdown]
# <hr>
#
# **[Problem 5] How many times is the second half as long as the first half?**
#
# <hr>

# %%
print("Check first half and second half of simple example 4x4")
arrd = mxn_mass(4,4)
print("4X4 square \n{}".format(arrd))
print("first half of 4x4 \n{}".format(arrd[0:2]))
print("second half of 4x4 \n{}\n".format(arrd[2:4]))

first_half = arr[0:4]
second_half = arr[4:8]

print("Back to 8x8 square\n")
print("first half of 8x8 \n{}".format(first_half))
print("\nsecond half of 8x8 \n{}\n".format(second_half))
print("the second half is geater {:.0f} times than the first half".format(second_half.sum() / first_half.sum()))
# Out:
# Check first half and second half of simple example 4x4
# 4X4 square
# [[    1     2     4     8]
#  [   16    32    64   128]
#  [  256   512  1024  2048]
#  [ 4096  8192 16384 32768]]
# first half of 4x4
# [[  1   2   4   8]
#  [ 16  32  64 128]]
# second half of 4x4
# [[  256   512  1024  2048]
#  [ 4096  8192 16384 32768]]
#
# Back to 8x8 square
#
# first half of 8x8
# [[1.00000000e+00 2.00000000e+00 4.00000000e+00 8.00000000e+00
#   1.60000000e+01 3.20000000e+01 6.40000000e+01 1.28000000e+02]
#  [2.56000000e+02 5.12000000e+02 1.02400000e+03 2.04800000e+03
#   4.09600000e+03 8.19200000e+03 1.63840000e+04 3.27680000e+04]
#  [6.55360000e+04 1.31072000e+05 2.62144000e+05 5.24288000e+05
#   1.04857600e+06 2.09715200e+06 4.19430400e+06 8.38860800e+06]
#  [1.67772160e+07 3.35544320e+07 6.71088640e+07 1.34217728e+08
#   2.68435456e+08 5.36870912e+08 1.07374182e+09 2.14748365e+09]]
#
# second half of 8x8
# [[4.29496730e+09 8.58993459e+09 1.71798692e+10 3.43597384e+10
# ...

# %% [markdown]
# <hr>
#
# **[Problem 6] Expansion to n × m mass by another calculation method**
#
# <hr>

# %%
def mxn_append_method(m, n):
    arr = np.array([1]).astype(np.uint64)
    for i in range(m*n - 1):
        arr = np.append(arr, 2*arr[-1]) 
    arr = arr.reshape(m,n)
    return arr


def mxn_broadcast_method(m, n):
    lists = np.arange(m*n).astype(np.uint64)
    arr = 2**lists
    arr = arr.reshape(m,n)
    return arr

arr_append = mxn_append_method(8,8)

print("in Append method 8x8 square is \n{}\n".format(arr_append))

arr_broadcast = mxn_broadcast_method(8,8)

print("in Broadcase method 8x8 square is \n{}\n".format(arr_append))
# Out:
# in Append method 8x8 square is
# [[1.00000000e+00 2.00000000e+00 4.00000000e+00 8.00000000e+00
#   1.60000000e+01 3.20000000e+01 6.40000000e+01 1.28000000e+02]
#  [2.56000000e+02 5.12000000e+02 1.02400000e+03 2.04800000e+03
#   4.09600000e+03 8.19200000e+03 1.63840000e+04 3.27680000e+04]
#  [6.55360000e+04 1.31072000e+05 2.62144000e+05 5.24288000e+05
#   1.04857600e+06 2.09715200e+06 4.19430400e+06 8.38860800e+06]
#  [1.67772160e+07 3.35544320e+07 6.71088640e+07 1.34217728e+08
#   2.68435456e+08 5.36870912e+08 1.07374182e+09 2.14748365e+09]
#  [4.29496730e+09 8.58993459e+09 1.71798692e+10 3.43597384e+10
#   6.87194767e+10 1.37438953e+11 2.74877907e+11 5.49755814e+11]
#  [1.09951163e+12 2.19902326e+12 4.39804651e+12 8.79609302e+12
#   1.75921860e+13 3.51843721e+13 7.03687442e+13 1.40737488e+14]
#  [2.81474977e+14 5.62949953e+14 1.12589991e+15 2.25179981e+15
#   4.50359963e+15 9.00719925e+15 1.80143985e+16 3.60287970e+16]
#  [7.20575940e+16 1.44115188e+17 2.88230376e+17 5.76460752e+17
# ...

# %% [markdown]
# <hr>
#
# **[Problem 7] Comparing calculation times**
#
# <hr>

# %%
# %%timeit
arr = mxn_mass(8,8)
# Out:
# 23.1 µs ± 2.89 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
arr = mxn_append_method(8,8)
# Out:
# 665 µs ± 43.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
arr = mxn_broadcast_method(8,8)
# Out:
# 5.52 µs ± 358 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# In this problem after using the magic cell run in 100000 loop. the Broadcast method has the smallest time in 5.53 us, and the Append method is the worst case with 665 us. My method mxn_mass seen to be the medium time around 23.1 us
